# %% [markdown]
# # 18АС | Пигасин Дмитрий | 6 Вариант

# %% [markdown]
# Установка Keras Tuner

# %%
# !pip install -U keras-tuner
# Out:
# Requirement already up-to-date: keras-tuner in /usr/local/lib/python3.6/dist-packages (1.0.1)
# Requirement already satisfied, skipping upgrade: terminaltables in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (3.1.0)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (1.4.1)
# Requirement already satisfied, skipping upgrade: tqdm in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (4.41.1)
# Requirement already satisfied, skipping upgrade: tabulate in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (0.8.7)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (2.23.0)
# Requirement already satisfied, skipping upgrade: colorama in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (0.4.3)
# Requirement already satisfied, skipping upgrade: scikit-learn in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: future in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (0.16.0)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (1.18.5)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->keras-tuner) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->keras-tuner) (1.24.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->keras-tuner) (2020.6.20)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->keras-tuner) (3.0.4)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->keras-tuner) (0.16.0)

# %% [markdown]
# Импорт модулей

# %%
import keras
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras.models import Sequential
from tensorflow.keras.callbacks import Callback
from kerastuner.tuners import Hyperband
import IPython

# %% [markdown]
# Загрузка данных с GDrive

# %%
data = pd.read_csv('/content/drive/My Drive/data_analysis/lab1/train.csv')
data
# Out:
#             id cat1 cat2 cat3  ...    cont12    cont13    cont14     loss
# 0            1    A    B    A  ...  0.594646  0.822493  0.714843  2213.18
# 1            2    A    B    A  ...  0.366307  0.611431  0.304496  1283.60
# 2            5    A    B    A  ...  0.373424  0.195709  0.774425  3005.09
# 3           10    B    B    A  ...  0.321570  0.605077  0.602642   939.85
# 4           11    A    B    A  ...  0.202213  0.246011  0.432606  2763.85
# ...        ...  ...  ...  ...  ...       ...       ...       ...      ...
# 188313  587620    A    B    A  ...  0.220003  0.333292  0.208216  1198.62
# 188314  587624    A    A    A  ...  0.301921  0.318646  0.305872  1108.34
# 188315  587630    A    B    A  ...  0.443374  0.339244  0.503888  5762.64
# 188316  587632    A    B    A  ...  0.852865  0.654753  0.721707  1562.87
# 188317  587633    B    A    A  ...  0.946432  0.810511  0.721460  4751.72
#
# [188318 rows x 132 columns]

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Разбиение на отдельные таблицы для дальнейшей нормализации

# %%
data_cat = data.get([f'cat{i}' for i in range(1, 117)])
data_cont = data.get([f'cont{i}' for i in range(1, 15)])
data_loss = data.get('loss')
del data

# %%
data_cat
# Out:
#        cat1 cat2 cat3 cat4 cat5 cat6  ... cat111 cat112 cat113 cat114 cat115 cat116
# 0         A    B    A    B    A    A  ...      C     AS      S      A      O     LB
# 1         A    B    A    A    A    A  ...      A     AV     BM      A      O     DP
# 2         A    B    A    A    B    A  ...      A      C     AF      A      I     GK
# 3         B    B    A    B    A    A  ...      C      N     AE      A      O     DJ
# 4         A    B    A    B    A    A  ...      C      Y     BM      A      K     CK
# ...     ...  ...  ...  ...  ...  ...  ...    ...    ...    ...    ...    ...    ...
# 188313    A    B    A    A    A    A  ...      A      G     BM      A      L     CK
# 188314    A    A    A    A    A    B  ...      A     AV     AU      E      J     DF
# 188315    A    B    A    A    A    A  ...      A      W     AF      A      K     DJ
# 188316    A    B    A    A    A    A  ...      A     AS     AJ      A      O     MD
# 188317    B    A    A    B    A    A  ...      K     AS     AD      A      O     MJ
#
# [188318 rows x 116 columns]

# %%
data_cont
# Out:
#            cont1     cont2     cont3  ...    cont12    cont13    cont14
# 0       0.726300  0.245921  0.187583  ...  0.594646  0.822493  0.714843
# 1       0.330514  0.737068  0.592681  ...  0.366307  0.611431  0.304496
# 2       0.261841  0.358319  0.484196  ...  0.373424  0.195709  0.774425
# 3       0.321594  0.555782  0.527991  ...  0.321570  0.605077  0.602642
# 4       0.273204  0.159990  0.527991  ...  0.202213  0.246011  0.432606
# ...          ...       ...       ...  ...       ...       ...       ...
# 188313  0.347403  0.785784  0.613660  ...  0.220003  0.333292  0.208216
# 188314  0.507661  0.555782  0.549770  ...  0.301921  0.318646  0.305872
# 188315  0.484469  0.785784  0.792378  ...  0.443374  0.339244  0.503888
# 188316  0.438385  0.422197  0.298977  ...  0.852865  0.654753  0.721707
# 188317  0.907272  0.620805  0.440642  ...  0.946432  0.810511  0.721460
#
# [188318 rows x 14 columns]

# %%
data_loss
# Out:
# 0         2213.18
# 1         1283.60
# 2         3005.09
# 3          939.85
# 4         2763.85
#            ...
# 188313    1198.62
# 188314    1108.34
# 188315    5762.64
# 188316    1562.87
# 188317    4751.72
# Name: loss, Length: 188318, dtype: float64

# %% [markdown]
# Оценка разброса значений

# %%
data_loss_sorted = list(data_loss.sort_values())
print(f'top 10 min {data_loss_sorted[:10]}\ntop 10 max {data_loss_sorted[:-10:-1]}')
del data_loss_sorted
# Out:
# top 10 min [0.67, 5.25, 6.0, 8.4, 10.0, 11.0, 20.11, 20.99, 21.0, 23.69]
# top 10 max [121012.25, 106863.0, 85923.56, 79623.52, 67667.16, 67537.73, 59826.79, 57224.55, 54190.39]

# %% [markdown]
# ### Нормализация данных

# %% [markdown]
# Категориальные данные

# %%
data_cat_label = pd.DataFrame()
label_encoder = LabelEncoder()

for i in range(1,117):
  data_cat_label[f'cat{i}'] = label_encoder.fit_transform(data_cat[f'cat{i}'])

data_cat_norm = (data_cat_label - data_cat_label.mean()) / data_cat_label.std()

del data_cat
del data_cat_label

# %%
data_cat_norm
# Out:
#             cat1      cat2      cat3  ...    cat114    cat115    cat116
# 0      -0.574802  1.143633 -0.240848  ... -0.542895  0.891654  1.578088
# 1      -0.574802  1.143633 -0.240848  ... -0.542895  0.891654 -0.909695
# 2      -0.574802  1.143633 -0.240848  ... -0.542895 -1.546435  0.009703
# 3       1.739720  1.143633 -0.240848  ... -0.542895  0.891654 -0.990818
# 4      -0.574802  1.143633 -0.240848  ... -0.542895 -0.733739 -1.315312
# ...          ...       ...       ...  ...       ...       ...       ...
# 188313 -0.574802  1.143633 -0.240848  ... -0.542895 -0.327391 -1.315312
# 188314 -0.574802 -0.874402 -0.240848  ...  0.952808 -1.140087 -1.044901
# 188315 -0.574802  1.143633 -0.240848  ... -0.542895 -0.733739 -0.990818
# 188316 -0.574802  1.143633 -0.240848  ... -0.542895  0.891654  1.929622
# 188317  1.739720 -0.874402 -0.240848  ... -0.542895  0.891654  2.010746
#
# [188318 rows x 116 columns]

# %% [markdown]
# Числовые данные

# %%
data_cont_norm = (data_cont - data_cont.mean()) / data_cont.std()
del data_cont

# %%
data_cont_norm
# Out:
#            cont1     cont2     cont3  ...    cont12    cont13    cont14
# 0       1.238747 -1.260932 -1.540467  ...  0.484635  1.547888  0.984891
# 1      -0.870535  1.109448  0.463931  ... -0.605670  0.555949 -0.859468
# 2      -1.236518 -0.718475 -0.072846  ... -0.571687 -1.397840  1.252690
# 3      -0.918073  0.234523  0.143849  ... -0.819287  0.526087  0.480589
# 4      -1.175960 -1.675654  0.143849  ... -1.389209 -1.161433 -0.283661
# ...          ...       ...       ...  ...       ...       ...       ...
# 188313 -0.780528  1.344562  0.567733  ... -1.304263 -0.751235 -1.292212
# 188314  0.073543  0.234523  0.251610  ... -0.913109 -0.820067 -0.853284
# 188315 -0.050055  1.344562  1.452018  ... -0.237680 -0.723262  0.036726
# 188316 -0.295653 -0.410187 -0.989297  ...  1.717616  0.759552  1.015742
# 188317  2.203210  0.548338 -0.288348  ...  2.164393  1.491576  1.014632
#
# [188318 rows x 14 columns]

# %% [markdown]
# Склейка обработанных таблиц воедино

# %%
data = pd.concat([data_cat_norm, data_cont_norm, data_loss], axis=1)
del data_cat_norm
del data_cont_norm
del data_loss
data
# Out:
#             cat1      cat2      cat3  ...    cont13    cont14     loss
# 0      -0.574802  1.143633 -0.240848  ...  1.547888  0.984891  2213.18
# 1      -0.574802  1.143633 -0.240848  ...  0.555949 -0.859468  1283.60
# 2      -0.574802  1.143633 -0.240848  ... -1.397840  1.252690  3005.09
# 3       1.739720  1.143633 -0.240848  ...  0.526087  0.480589   939.85
# 4      -0.574802  1.143633 -0.240848  ... -1.161433 -0.283661  2763.85
# ...          ...       ...       ...  ...       ...       ...      ...
# 188313 -0.574802  1.143633 -0.240848  ... -0.751235 -1.292212  1198.62
# 188314 -0.574802 -0.874402 -0.240848  ... -0.820067 -0.853284  1108.34
# 188315 -0.574802  1.143633 -0.240848  ... -0.723262  0.036726  5762.64
# 188316 -0.574802  1.143633 -0.240848  ...  0.759552  1.015742  1562.87
# 188317  1.739720 -0.874402 -0.240848  ...  1.491576  1.014632  4751.72
#
# [188318 rows x 131 columns]

# %% [markdown]
# ### Разбиение на обучающую и тестовую выборки

# %%
split = 0.7
random_seed = 200

y_data = data.get('loss')
x_data = data.drop(['loss'], axis=1)
del data

x_train = x_data.sample(frac=split, random_state=random_seed)
x_test = x_data.drop(x_train.index)

y_train = y_data.sample(frac=split, random_state=random_seed)
y_test = y_data.drop(y_train.index)

del x_data
del y_data

# %% [markdown]
# Просмотр тренировочных данных

# %%
x_train
# Out:
#             cat1      cat2      cat3  ...    cont12    cont13    cont14
# 35320  -0.574802  1.143633  4.151980  ...  1.057142  1.214272  1.336758
# 11967   1.739720  1.143633 -0.240848  ... -0.520227 -1.016366  1.449636
# 16312  -0.574802  1.143633 -0.240848  ...  0.034530  0.925082 -0.486221
# 97332  -0.574802 -0.874402 -0.240848  ...  1.717616 -0.820067 -0.624201
# 41478  -0.574802  1.143633  4.151980  ... -0.672787 -0.723262  0.983466
# ...          ...       ...       ...  ...       ...       ...       ...
# 130089  1.739720 -0.874402 -0.240848  ...  0.950718 -0.637933  0.478323
# 146720 -0.574802  1.143633 -0.240848  ...  0.484635  0.787765  0.483942
# 54392   1.739720  1.143633 -0.240848  ... -0.605670  0.555949 -1.159135
# 172723  1.739720 -0.874402 -0.240848  ... -0.183575  0.829630  1.483728
# 22367  -0.574802  1.143633 -0.240848  ... -1.200776 -0.491446  1.025091
#
# [131823 rows x 130 columns]

# %%
y_train
# Out:
# 35320     5667.98
# 11967     6668.04
# 16312      720.40
# 97332     5361.27
# 41478      867.82
#            ...
# 130089     608.43
# 146720    2527.17
# 54392      641.47
# 172723    3532.58
# 22367     2974.41
# Name: loss, Length: 131823, dtype: float64

# %% [markdown]
# ## Тест предобученной модели

# %%
model = keras.models.load_model('/content/drive/My Drive/data_analysis/lab1/model_cat_norm_mae_1187.h5')
mae = model.evaluate(x_test, y_test, verbose=0)[1]
print(f'Средняя абсолютная ошибка = {mae}')
# Out:
# Средняя абсолютная ошибка = 1187.811279296875

# %% [markdown]
# ## Создание нейронной сети

# %% [markdown]
# Описание модели

# %%
def build_model(hp):
  activation_choice = hp.Choice('activation', values=['relu', 'sigmoid', 'tanh', 'elu', 'selu'])
  optimizer_choice = hp.Choice('optimizer', values=['adam', 'rmsprop', 'SGD'])
  hidden_layers_choice = hp.Choice('hidden_layers', values=[0, 1, 2])

  model = Sequential()
  model.add(
      Dense(
          units=hp.Int(
              'input_units',
              min_value=128, 
              max_value=256, 
              step=16,
          ), 
          input_dim=x_train.shape[1], 
          activation=activation_choice,
      ),
  )
  for i in range(hidden_layers_choice):
    model.add(
        Dense(
            units=hp.Int(
                f'layer_{i + 1}_units',
                min_value=64 // (i + 1),
                max_value=128 // (i + 1),
                step=8 // (i + 1),
            ),
            activation=activation_choice
        )
    )
  model.add(Dense(1))

  model.compile(
      optimizer=optimizer_choice, 
      loss='mae',
      metrics=['mae'], 
  )

  return model

# %% [markdown]
# Создание тюнера

# %%
tuner = Hyperband(
    build_model,
    objective='mae', 
    max_epochs=10,
    directory='models',
    project_name='lab1',
)

# %%
tuner.search_space_summary()
# Out:
# <span style="color:#4527A0"><h1 style="font-size:18px">Search space summary</h1></span>
# <span style="color:cyan"> |-Default search space size: 4</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">activation (Choice)</h2></span>
# <span style="color:cyan"> |-default: relu</span>
# <span style="color:blue"> |-ordered: False</span>
# <span style="color:cyan"> |-values: ['relu', 'sigmoid', 'tanh', 'elu', 'selu']</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">optimizer (Choice)</h2></span>
# <span style="color:cyan"> |-default: adam</span>
# <span style="color:blue"> |-ordered: False</span>
# <span style="color:cyan"> |-values: ['adam', 'rmsprop', 'SGD']</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">hidden_layers (Choice)</h2></span>
# <span style="color:cyan"> |-default: 0</span>
# <span style="color:blue"> |-ordered: True</span>
# <span style="color:cyan"> |-values: [0, 1, 2]</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">input_units (Int)</h2></span>
# <span style="color:cyan"> |-default: None</span>
# <span style="color:blue"> |-max_value: 256</span>
# <span style="color:cyan"> |-min_value: 128</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 16</span>

# %% [markdown]
# Callback для очистки результатов в конце каждого шага обучения

# %%
class ClearTrainingOutput(Callback):
  def on_train_end(*args, **kwargs):
    IPython.display.clear_output(wait = True)

# %% [markdown]
# Поиск оптимальных гиперпараметров

# %%
tuner.search(
    x_train,
    y_train,
    validation_split=0.2,
    verbose=2,
    callbacks = [ClearTrainingOutput()],
)
# Out:
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 48ce6aaabb5f7a4fc7095f51453f84e5</span>
# <span style="color:cyan"> |-Score: 1671.61376953125</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-activation: tanh</span>
# <span style="color:blue"> |-hidden_layers: 0</span>
# <span style="color:cyan"> |-input_units: 224</span>
# <span style="color:blue"> |-layer_1_units: 88</span>
# <span style="color:cyan"> |-layer_2_units: 44</span>
# <span style="color:blue"> |-optimizer: rmsprop</span>
# <span style="color:cyan"> |-tuner/bracket: 0</span>
# <span style="color:blue"> |-tuner/epochs: 10</span>
# <span style="color:cyan"> |-tuner/initial_epoch: 0</span>
# <span style="color:blue"> |-tuner/round: 0</span>
# INFO:tensorflow:Oracle triggered exit

# %% [markdown]
# Создание модели на основе найденных гиперпараметров

# %%
best_hps = tuner.get_best_hyperparameters()[0]
model = tuner.hypermodel.build(best_hps)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 208)               27248
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                13376
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 42,737
# Trainable params: 42,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, epochs=15, batch_size=64, validation_split=0.2, verbose=2)
# Out:
# Epoch 1/15
# 1648/1648 - 4s - loss: 1449.8792 - mae: 1449.8792 - val_loss: 1233.9685 - val_mae: 1233.9685
# Epoch 2/15
# 1648/1648 - 4s - loss: 1215.5631 - mae: 1215.5631 - val_loss: 1224.1688 - val_mae: 1224.1688
# Epoch 3/15
# 1648/1648 - 4s - loss: 1201.5421 - mae: 1201.5421 - val_loss: 1213.8414 - val_mae: 1213.8414
# Epoch 4/15
# 1648/1648 - 4s - loss: 1192.0818 - mae: 1192.0818 - val_loss: 1205.9368 - val_mae: 1205.9368
# Epoch 5/15
# 1648/1648 - 4s - loss: 1184.8489 - mae: 1184.8489 - val_loss: 1201.8843 - val_mae: 1201.8843
# Epoch 6/15
# 1648/1648 - 4s - loss: 1178.6202 - mae: 1178.6202 - val_loss: 1199.0049 - val_mae: 1199.0049
# Epoch 7/15
# 1648/1648 - 4s - loss: 1173.4622 - mae: 1173.4622 - val_loss: 1195.2734 - val_mae: 1195.2734
# Epoch 8/15
# 1648/1648 - 4s - loss: 1167.8845 - mae: 1167.8845 - val_loss: 1195.4564 - val_mae: 1195.4564
# Epoch 9/15
# 1648/1648 - 4s - loss: 1162.8655 - mae: 1162.8655 - val_loss: 1194.3373 - val_mae: 1194.3373
# Epoch 10/15
# 1648/1648 - 4s - loss: 1159.1501 - mae: 1159.1501 - val_loss: 1192.5122 - val_mae: 1192.5122
# Epoch 11/15
# 1648/1648 - 4s - loss: 1155.0414 - mae: 1155.0414 - val_loss: 1197.3899 - val_mae: 1197.3899
# Epoch 12/15
# 1648/1648 - 4s - loss: 1150.4534 - mae: 1150.4534 - val_loss: 1193.8073 - val_mae: 1193.8073
# Epoch 13/15
# 1648/1648 - 4s - loss: 1147.1464 - mae: 1147.1464 - val_loss: 1193.4513 - val_mae: 1193.4513
# Epoch 14/15
# 1648/1648 - 4s - loss: 1143.2582 - mae: 1143.2582 - val_loss: 1192.8082 - val_mae: 1192.8082
# Epoch 15/15
# 1648/1648 - 4s - loss: 1138.7817 - mae: 1138.7817 - val_loss: 1196.1624 - val_mae: 1196.1624

# %% [markdown]
# ## Оценка результатов обучения

# %%
mae = model.evaluate(x_test, y_test, verbose=0)[1]
print(f'Средняя абсолютная ошибка = {mae}')
# Out:
# Средняя абсолютная ошибка = 1187.811279296875

# %% [markdown]
# Топ Kaggle
# https://www.kaggle.com/c/allstate-claims-severity/leaderboard

# %% [markdown]
# Сохранение модели

# %%
model.save(f'/content/drive/My Drive/data_analysis/lab1/model_cat_norm_mae_{int(mae)}.h5')
